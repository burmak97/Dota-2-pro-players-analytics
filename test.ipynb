# %%
import pandas as pd
import requests
import time
import numpy as np
import panel as pn
import json
pn.extension('tabulator')
import hvplot.pandas
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
players = pd.read_json('JSON_DATA/pro_players_list.json')

# %%
players[players.team_tag=='TSpirit']
# Out:
#       account_id            steamid  \
# 822    113331514  76561198073597248
# 2047   256156323  76561198216422048
# 2161   302214028  76561198262479760
# 2224   321580662  76561198281846384
# 2528   431770905  76561198392036640
#
#                                                  avatar  \
# 822   https://avatars.akamai.steamstatic.com/448b737...
# 2047  https://avatars.akamai.steamstatic.com/cbd6a57...
# 2161  https://avatars.akamai.steamstatic.com/74c5f6d...
# 2224  https://avatars.akamai.steamstatic.com/7d5291e...
# 2528  https://avatars.akamai.steamstatic.com/461d567...
#
#                                            avatarmedium  \
# 822   https://avatars.akamai.steamstatic.com/448b737...
# 2047  https://avatars.akamai.steamstatic.com/cbd6a57...
# 2161  https://avatars.akamai.steamstatic.com/74c5f6d...
# 2224  https://avatars.akamai.steamstatic.com/7d5291e...
# 2528  https://avatars.akamai.steamstatic.com/461d567...
#
#                                              avatarfull  \
# ...
